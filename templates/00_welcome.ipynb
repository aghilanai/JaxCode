# %% [markdown]
# # 🔥 Welcome to JaxCode
#
# **Crack the JAX / Flax NNX interview.**
#
# Practice implementing operators and architectures from scratch — graded instantly by `jax_judge`.
#
# ## How to use
#
# 1. Open a problem notebook (e.g. `01_relu.ipynb`)
# 2. Implement the function or `nnx.Module`
# 3. Run `check("task_id")` — or use the **Run Tests** toolbar button
#
# ```python
# from jax_judge import status, check, hint
# status()
# ```

# %%
# Install jax-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q jax-judge')
except ImportError:
    pass

# %%
from jax_judge import status, check, hint
status()
