# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/02_softmax_solution.ipynb)
#
# # ✅ Solution: Implement Softmax
#
# Implement the **Softmax** function from scratch.
#
# $$\text{softmax}(x_i) = \frac{e^{x_i}}{\sum_j e^{x_j}}$$
#
# ### Signature
# ```python
# def my_softmax(x: jax.Array, dim: int = -1) -> jax.Array:
#     ...
# ```
#
# ### Rules
# - Do **NOT** use `jax.nn.softmax`, `jax.nn.softmax`, or `jax.nn.Softmax`
# - Must be **numerically stable** (hint: subtract `max` before `exp`)
#
# ### Example
# ```
# Input:  array([1., 2., 3.])
# Output: array([0.0900, 0.2447, 0.6652])  # sums to 1.0
# ```

# %%
# Install jax-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q jax-judge')
except ImportError:
    pass

# %%
import jax
import jax.numpy as jnp
import math

# %%
# ✅ SOLUTION

import jax.numpy as jnp
def my_softmax(x, dim=-1):
    z = x - jnp.max(x, axis=dim, keepdims=True)
    e = jnp.exp(z)
    return e / jnp.sum(e, axis=dim, keepdims=True)

# %%
# Verify
print(my_softmax)

# %%
from jax_judge import check
check("softmax")
